# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import xgboost as xgb


# %matplotlib inline
plt.style.use('ggplot')

# %%
train_data = pd.read_csv("train_data.csv")
test_data = pd.read_csv("test_data.csv").drop("Unnamed: 0", axis=1)
train_target = pd.read_csv("train_target.csv")

print("Shapes of data:", train_data.shape, test_data.shape, train_target.shape)
print("Proportion train/test: ", int(train_data.shape[0]/test_data.shape[0]))
# Out:
# Shapes of data: (27594, 20) (13593, 20) (27594, 1)
# Proportion train/test:  2

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from pandas import get_dummies

# %%
le = LabelEncoder()
train_data = train_data.apply(le.fit_transform)

# %%
train_data = pd.get_dummies(train_data)

# %%
train_data, train_target = np.array(train_data), np.array(train_target)
c, r = train_target.shape
train_target = train_target.reshape(c,)

# %% [markdown]
# ### XGBoost

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score

# %%
def xgb_grid_search(data, target):
    
    X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=442)

    gbm_params = {"n_estimators": [100, 150, 200, 300, 350], 
                  "max_depth" : [3, 5, 7, 10], 
                  "reg_lambda" : [1, 2, 3, 5]}

    print("GridSeachCV proceeding...")
    gbm = GridSearchCV(xgb.XGBClassifier(), gbm_params, n_jobs=3, cv=3, verbose=2)
    gbm.fit(X_train, y_train)
    print("Done.")
    
    print(101*"="+ "\nBEST PARAMETERS: ", gbm.best_params_, "\n"+101*"="+"\n")
    predictions = gbm.best_estimator_.predict(X_test)
    
    
    print("==================\nACCURACY : %.4g\n==================" % accuracy_score(y_test, predictions))
    return pd.Seriespredictions

# %%
xgb_grid_search(train_data, train_target)
# Out:
# GridSeachCV proceeding...
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV] reg_lambda=1, n_estimators=100, max_depth=3 .....................
# [CV] reg_lambda=1, n_estimators=100, max_depth=3 .....................
# [CV] reg_lambda=1, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=3 -   5.4s
# [CV] reg_lambda=2, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=3 -   5.6s
# [CV] reg_lambda=2, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=3 -   6.2s
# [CV] reg_lambda=2, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=3 -   5.4s
# [CV] reg_lambda=3, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=3 -   4.7s
# [CV] reg_lambda=3, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=3 -   5.7s
# [CV] reg_lambda=3, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=3 -   6.4s
# [CV] reg_lambda=5, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=3 -   6.2s
# [CV] reg_lambda=5, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=3 -   7.2s
# [CV] reg_lambda=5, n_estimators=100, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=3 -   6.5s
# [CV] reg_lambda=1, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=3 -   6.5s
# [CV] reg_lambda=1, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=3 -   6.6s
# [CV] reg_lambda=1, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=3 -   9.2s
# [CV] reg_lambda=2, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=3 -   9.7s
# [CV] reg_lambda=2, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=3 -   9.6s
# [CV] reg_lambda=2, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=3 -   9.9s
# [CV] reg_lambda=3, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=3 -  10.1s
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=3 -   9.5s
# [CV] reg_lambda=3, n_estimators=150, max_depth=3 .....................
# [CV] reg_lambda=3, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=3 -  10.0s
# [CV] reg_lambda=5, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=3 -  10.5s
# [CV] reg_lambda=5, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=3 -  10.9s
# [CV] reg_lambda=5, n_estimators=150, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=3 -  10.8s
# [CV] reg_lambda=1, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=3 -  10.1s
# [CV] reg_lambda=1, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=3 -  10.9s
# [CV] reg_lambda=1, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=3 -  13.6s
# [CV] reg_lambda=2, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=3 -  13.7s
# [CV] reg_lambda=2, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=3 -  14.0s
# [CV] reg_lambda=2, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=3 -  15.9s
# [CV] reg_lambda=3, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=3 -  15.5s
# [CV] reg_lambda=3, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=3 -  16.8s
# [CV] reg_lambda=3, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=3 -  14.0s
# [CV] reg_lambda=5, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=3 -  14.9s
# [CV] reg_lambda=5, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=3 -  13.5s
# [CV] reg_lambda=5, n_estimators=200, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=3 -  18.3s
# [CV] reg_lambda=1, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=3 -  18.6s
# [CV] reg_lambda=1, n_estimators=300, max_depth=3 .....................
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:  2.1min
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=3 -  18.2s
# [CV] reg_lambda=1, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=3 -  21.3s
# [CV] reg_lambda=2, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=3 -  21.1s
# [CV] reg_lambda=2, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=3 -  21.9s
# [CV] reg_lambda=2, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=3 -  23.1s
# [CV] reg_lambda=3, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=3 -  23.5s
# [CV] reg_lambda=3, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=3 -  23.9s
# [CV] reg_lambda=3, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=3 -  25.5s
# [CV] reg_lambda=5, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=3 -  24.9s
# [CV] reg_lambda=5, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=3 -  26.0s
# [CV] reg_lambda=5, n_estimators=300, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=3 -  22.2s
# [CV] reg_lambda=1, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=3 -  22.3s
# [CV] reg_lambda=1, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=3 -  21.9s
# [CV] reg_lambda=1, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=3 -  26.8s
# [CV] reg_lambda=2, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=3 -  26.5s
# [CV] reg_lambda=2, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=3 -  28.5s
# [CV] reg_lambda=2, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=3 -  28.7s
# [CV] reg_lambda=3, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=3 -  29.1s
# [CV] reg_lambda=3, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=3 -  27.6s
# [CV] reg_lambda=3, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=3 -  29.5s
# [CV] reg_lambda=5, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=3 -  29.3s
# [CV] reg_lambda=5, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=3 -  29.3s
# [CV] reg_lambda=5, n_estimators=350, max_depth=3 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=3 -  25.2s
# [CV] reg_lambda=1, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=3 -  25.6s
# [CV] reg_lambda=1, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=3 -  24.5s
# [CV] reg_lambda=1, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=5 -  11.1s
# [CV] reg_lambda=2, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=5 -  10.9s
# [CV] reg_lambda=2, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=5 -  12.3s
# [CV] reg_lambda=2, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=5 -  13.9s
# [CV] reg_lambda=3, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=5 -  15.0s
# [CV] reg_lambda=3, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=5 -  15.5s
# [CV] reg_lambda=3, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=5 -  14.4s
# [CV] reg_lambda=5, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=5 -  13.8s
# [CV] reg_lambda=5, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=5 -  12.9s
# [CV] reg_lambda=5, n_estimators=100, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=5 -  11.8s
# [CV] reg_lambda=1, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=5 -  10.9s
# [CV] reg_lambda=1, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=5 -  11.7s
# [CV] reg_lambda=1, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=5 -  16.8s
# [CV] reg_lambda=2, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=5 -  16.3s
# [CV] reg_lambda=2, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=5 -  17.1s
# [CV] reg_lambda=2, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=5 -  18.2s
# [CV] reg_lambda=3, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=5 -  19.8s
# [CV] reg_lambda=3, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=5 -  18.0s
# [CV] reg_lambda=3, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=5 -  18.6s
# [CV] reg_lambda=5, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=5 -  18.4s
# [CV] reg_lambda=5, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=5 -  19.1s
# [CV] reg_lambda=5, n_estimators=150, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=5 -  16.7s
# [CV] reg_lambda=1, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=5 -  17.5s
# [CV] reg_lambda=1, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=5 -  17.9s
# [CV] reg_lambda=1, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=5 -  22.6s
# [CV] reg_lambda=2, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=5 -  23.4s
# [CV] reg_lambda=2, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=5 -  23.1s
# [CV] reg_lambda=2, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=5 -  21.0s
# [CV] reg_lambda=3, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=5 -  22.0s
# [CV] reg_lambda=3, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=5 -  23.1s
# [CV] reg_lambda=3, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=5 -  22.4s
# [CV] reg_lambda=5, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=5 -  24.1s
# [CV] reg_lambda=5, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=5 -  23.5s
# [CV] reg_lambda=5, n_estimators=200, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=5 -  24.6s
# [CV] reg_lambda=1, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=5 -  23.3s
# [CV] reg_lambda=1, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=5 -  23.6s
# [CV] reg_lambda=1, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=5 -  37.8s
# [CV] reg_lambda=2, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=5 -  36.7s
# [CV] reg_lambda=2, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=5 -  35.0s
# [CV] reg_lambda=2, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=5 -  36.5s
# [CV] reg_lambda=3, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=5 -  36.8s
# [CV] reg_lambda=3, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=5 -  37.4s
# [CV] reg_lambda=3, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=5 -  34.9s
# [CV] reg_lambda=5, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=5 -  34.3s
# [CV] reg_lambda=5, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=5 -  36.5s
# [CV] reg_lambda=5, n_estimators=300, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=5 -  32.7s
# [CV] reg_lambda=1, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=5 -  33.7s
# [CV] reg_lambda=1, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=5 -  32.3s
# [CV] reg_lambda=1, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=5 -  40.9s
# [CV] reg_lambda=2, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=5 -  40.4s
# [CV] reg_lambda=2, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=5 -  40.8s
# [CV] reg_lambda=2, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=5 -  39.6s
# [CV] reg_lambda=3, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=5 -  39.4s
# [CV] reg_lambda=3, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=5 -  40.0s
# [CV] reg_lambda=3, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=5 -  40.1s
# [CV] reg_lambda=5, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=5 -  43.0s
# [CV] reg_lambda=5, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=5 -  41.5s
# [CV] reg_lambda=5, n_estimators=350, max_depth=5 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=5 -  39.8s
# [CV] reg_lambda=1, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=5 -  39.0s
# [CV] reg_lambda=1, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=5 -  39.9s
# [CV] reg_lambda=1, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=7 -  16.9s
# [CV] reg_lambda=2, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=7 -  15.9s
# [CV] reg_lambda=2, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=100, max_depth=7 -  15.3s
# [CV] reg_lambda=2, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=7 -  16.5s
# [CV] reg_lambda=3, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=7 -  16.9s
# [CV] reg_lambda=3, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=100, max_depth=7 -  17.6s
# [CV] reg_lambda=3, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=7 -  17.2s
# [CV] reg_lambda=5, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=7 -  17.2s
# [CV] reg_lambda=5, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=100, max_depth=7 -  16.8s
# [CV] reg_lambda=5, n_estimators=100, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=7 -  16.4s
# [CV] reg_lambda=1, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=7 -  15.7s
# [CV] reg_lambda=1, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=100, max_depth=7 -  16.3s
# [CV] reg_lambda=1, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=7 -  25.7s
# [CV] reg_lambda=2, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=7 -  24.5s
# [CV] reg_lambda=2, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=150, max_depth=7 -  25.6s
# [CV] reg_lambda=2, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=7 -  25.4s
# [CV] reg_lambda=3, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=7 -  25.1s
# [CV] reg_lambda=3, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=150, max_depth=7 -  24.2s
# [CV] reg_lambda=3, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=7 -  24.9s
# [CV] reg_lambda=5, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=7 -  24.5s
# [CV] reg_lambda=5, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=150, max_depth=7 -  26.1s
# [CV] reg_lambda=5, n_estimators=150, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=7 -  24.1s
# [CV] reg_lambda=1, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=7 -  26.1s
# [CV] reg_lambda=1, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=150, max_depth=7 -  24.6s
# [CV] reg_lambda=1, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=7 -  33.2s
# [CV] reg_lambda=2, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=7 -  33.0s
# [CV] reg_lambda=2, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=200, max_depth=7 -  34.8s
# [CV] reg_lambda=2, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=7 -  33.7s
# [CV] reg_lambda=3, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=7 -  34.1s
# [CV] reg_lambda=3, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=200, max_depth=7 -  33.8s
# [CV] reg_lambda=3, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=7 -  34.6s
# [CV] reg_lambda=5, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=7 -  34.1s
# [CV] reg_lambda=5, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=200, max_depth=7 -  36.5s
# [CV] reg_lambda=5, n_estimators=200, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=7 -  32.8s
# [CV] reg_lambda=1, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=7 -  35.5s
# [CV] reg_lambda=1, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=200, max_depth=7 -  32.4s
# [CV] reg_lambda=1, n_estimators=300, max_depth=7 .....................
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed: 19.3min
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=7 -  52.5s
# [CV] reg_lambda=2, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=7 -  53.6s
# [CV] reg_lambda=2, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=300, max_depth=7 -  54.0s
# [CV] reg_lambda=2, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=7 -  53.2s
# [CV] reg_lambda=3, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=7 -  55.4s
# [CV] reg_lambda=3, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=300, max_depth=7 -  56.8s
# [CV] reg_lambda=3, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=7 -  52.4s
# [CV] reg_lambda=5, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=7 -  50.3s
# [CV] reg_lambda=5, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=300, max_depth=7 -  49.4s
# [CV] reg_lambda=5, n_estimators=300, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=7 -  51.3s
# [CV] reg_lambda=1, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=7 -  53.8s
# [CV] reg_lambda=1, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=300, max_depth=7 -  55.1s
# [CV] reg_lambda=1, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=7 - 1.1min
# [CV] reg_lambda=2, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=7 - 1.0min
# [CV] reg_lambda=2, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=1, n_estimators=350, max_depth=7 - 1.0min
# [CV] reg_lambda=2, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=7 -  58.1s
# [CV] reg_lambda=3, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=7 - 1.0min
# [CV] reg_lambda=3, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=2, n_estimators=350, max_depth=7 - 1.0min
# [CV] reg_lambda=3, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=7 - 1.0min
# [CV] reg_lambda=5, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=7 -  58.4s
# [CV] reg_lambda=5, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=3, n_estimators=350, max_depth=7 -  59.6s
# [CV] reg_lambda=5, n_estimators=350, max_depth=7 .....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=7 -  59.9s
# [CV] reg_lambda=1, n_estimators=100, max_depth=10 ....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=7 -  59.4s
# [CV] reg_lambda=1, n_estimators=100, max_depth=10 ....................
# [CV] ............ reg_lambda=5, n_estimators=350, max_depth=7 - 1.0min
# [CV] reg_lambda=1, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=100, max_depth=10 -  25.2s
# [CV] reg_lambda=2, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=100, max_depth=10 -  25.4s
# [CV] reg_lambda=2, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=100, max_depth=10 -  25.6s
# [CV] reg_lambda=2, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=100, max_depth=10 -  24.5s
# [CV] reg_lambda=3, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=100, max_depth=10 -  24.6s
# [CV] reg_lambda=3, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=100, max_depth=10 -  25.2s
# [CV] reg_lambda=3, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=100, max_depth=10 -  24.3s
# [CV] reg_lambda=5, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=100, max_depth=10 -  23.6s
# [CV] reg_lambda=5, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=100, max_depth=10 -  23.7s
# [CV] reg_lambda=5, n_estimators=100, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=100, max_depth=10 -  24.6s
# [CV] reg_lambda=1, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=100, max_depth=10 -  25.5s
# [CV] reg_lambda=1, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=100, max_depth=10 -  22.9s
# [CV] reg_lambda=1, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=150, max_depth=10 -  37.3s
# [CV] reg_lambda=2, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=150, max_depth=10 -  35.1s
# [CV] reg_lambda=2, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=150, max_depth=10 -  36.3s
# [CV] reg_lambda=2, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=150, max_depth=10 -  34.6s
# [CV] reg_lambda=3, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=150, max_depth=10 -  34.5s
# [CV] reg_lambda=3, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=150, max_depth=10 -  35.2s
# [CV] reg_lambda=3, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=150, max_depth=10 -  38.0s
# [CV] reg_lambda=5, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=150, max_depth=10 -  37.7s
# [CV] reg_lambda=5, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=150, max_depth=10 -  36.5s
# [CV] reg_lambda=5, n_estimators=150, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=150, max_depth=10 -  38.1s
# [CV] reg_lambda=1, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=150, max_depth=10 -  36.8s
# [CV] reg_lambda=1, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=150, max_depth=10 -  35.2s
# [CV] reg_lambda=1, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=200, max_depth=10 -  48.8s
# [CV] reg_lambda=2, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=200, max_depth=10 -  47.9s
# [CV] reg_lambda=2, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=200, max_depth=10 -  47.4s
# [CV] reg_lambda=2, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=200, max_depth=10 -  49.4s
# [CV] reg_lambda=3, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=200, max_depth=10 -  48.8s
# [CV] reg_lambda=3, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=200, max_depth=10 -  48.3s
# [CV] reg_lambda=3, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=200, max_depth=10 -  50.3s
# [CV] reg_lambda=5, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=200, max_depth=10 -  50.9s
# [CV] reg_lambda=5, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=200, max_depth=10 -  49.7s
# [CV] reg_lambda=5, n_estimators=200, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=200, max_depth=10 -  49.7s
# [CV] reg_lambda=1, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=200, max_depth=10 -  50.2s
# [CV] reg_lambda=1, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=200, max_depth=10 -  49.6s
# [CV] reg_lambda=1, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=300, max_depth=10 - 1.2min
# [CV] reg_lambda=2, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=2, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=300, max_depth=10 - 1.2min
# [CV] reg_lambda=2, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=3, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=3, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=3, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=5, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=5, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=300, max_depth=10 - 1.2min
# [CV] reg_lambda=5, n_estimators=300, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=300, max_depth=10 - 1.2min
# [CV] reg_lambda=1, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=1, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=300, max_depth=10 - 1.3min
# [CV] reg_lambda=1, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=2, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=2, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=1, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=2, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=3, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=3, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=2, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=3, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=350, max_depth=10 - 1.6min
# [CV] reg_lambda=5, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=5, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=3, n_estimators=350, max_depth=10 - 1.5min
# [CV] reg_lambda=5, n_estimators=350, max_depth=10 ....................
# [CV] ........... reg_lambda=5, n_estimators=350, max_depth=10 - 1.5min
# [CV] ........... reg_lambda=5, n_estimators=350, max_depth=10 - 1.5min
# [CV] ........... reg_lambda=5, n_estimators=350, max_depth=10 - 1.5min
# [Parallel(n_jobs=3)]: Done 240 out of 240 | elapsed: 45.2min finished
# Done.
# =====================================================================================================
# BEST PARAMETERS:  {'reg_lambda': 1, 'n_estimators': 100, 'max_depth': 3}
# =====================================================================================================
#
# ==================
# ACCURACY : 0.8893
# ==================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-236-e9625f78e10d> in <module>()
# ----> 1 xgb_grid_search(train_data, train_target)
#
# <ipython-input-235-4e88ffaacc78> in xgb_grid_search(data, target)
#      17
#      18     print("==================\nACCURACY : %.4g\n==================" % accuracy_score(y_test, predictions))
# ---> 19     return pd.Seriespredictions
#      20
#
# AttributeError: module 'pandas' has no attribute 'Seriespredictions'
